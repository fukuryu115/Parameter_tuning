# %% [markdown]
# # MNISTの学習

# %%
run ../src/MNIST/MNIST_train.py
# Out:
# step
#
# Train start
# Training: 1 epoch. 100 iteration. Loss: 0.10452769696712494
# Training: 1 epoch. 200 iteration. Loss: 0.12952560186386108
# Training: 1 epoch. 300 iteration. Loss: 0.03923053666949272
# Training: 1 epoch. 400 iteration. Loss: 0.08098762482404709
# Training loss (ave.): 0.1816125776368513
#
# Validation start
# Validation loss: 6.760130116079427, Accuracy: 0.983
#
# step
#
# Train start
# Training: 2 epoch. 100 iteration. Loss: 0.10566181689500809
# Training: 2 epoch. 200 iteration. Loss: 0.036343205720186234
# Training: 2 epoch. 300 iteration. Loss: 0.036571916192770004
# Training: 2 epoch. 400 iteration. Loss: 0.027943512424826622
# Training loss (ave.): 0.051565959139157146
#
# Validation start
# Validation loss: 4.942871680341756, Accuracy: 0.9866
#
# step
#
# Train start
# Training: 3 epoch. 100 iteration. Loss: 0.06452947109937668
# Training: 3 epoch. 200 iteration. Loss: 0.0379943773150444
# Training: 3 epoch. 300 iteration. Loss: 0.004575333558022976
# Training: 3 epoch. 400 iteration. Loss: 0.04755518212914467
# Training loss (ave.): 0.03830363080084229
#
# Validation start
# Validation loss: 5.638293168330683, Accuracy: 0.985
#
# 0.9999015
# {'train_loss': [0.1816125776368513, 0.051565959139157146, 0.03830363080084229], 'validation_loss': [6.760130116079427, 4.942871680341756, 5.638293168330683], 'validation_acc': [0.983, 0.9866, 0.985]}

# %% [markdown]
# # Tensorboardでの確認

# %%
# !tensorboard --logdir ../logs/MNIST --port 6001 --bind_all
# Out:
# 2023-07-12 13:48:40.339897: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# /opt/conda/lib/python3.10/site-packages/tensorboard_data_server/bin/server: /lib/x86_64-linux-gnu/libc.so.6: version `GLIBC_2.29' not found (required by /opt/conda/lib/python3.10/site-packages/tensorboard_data_server/bin/server)
# /opt/conda/lib/python3.10/site-packages/tensorboard_data_server/bin/server: /lib/x86_64-linux-gnu/libc.so.6: version `GLIBC_2.33' not found (required by /opt/conda/lib/python3.10/site-packages/tensorboard_data_server/bin/server)
# /opt/conda/lib/python3.10/site-packages/tensorboard_data_server/bin/server: /lib/x86_64-linux-gnu/libc.so.6: version `GLIBC_2.28' not found (required by /opt/conda/lib/python3.10/site-packages/tensorboard_data_server/bin/server)
# /opt/conda/lib/python3.10/site-packages/tensorboard_data_server/bin/server: /lib/x86_64-linux-gnu/libc.so.6: version `GLIBC_2.34' not found (required by /opt/conda/lib/python3.10/site-packages/tensorboard_data_server/bin/server)
# /opt/conda/lib/python3.10/site-packages/tensorboard_data_server/bin/server: /lib/x86_64-linux-gnu/libc.so.6: version `GLIBC_2.32' not found (required by /opt/conda/lib/python3.10/site-packages/tensorboard_data_server/bin/server)
# E0712 13:48:41.164918 140109376172160 program.py:298] TensorBoard could not bind to port 6001, it was already in use
# ERROR: TensorBoard could not bind to port 6001, it was already in use

# %% [markdown]
# # パラメータの変更

# %%
run ../src/MNIST/MNIST_train --epoch 30
# Out:
# usage: MNIST_train.py [-h] [--epoch EPOCH] [--activation ACTIVATION]
#                       [--optimizer OPTIMIZER] [--weight_decay WEIGHT_DECAY]
#                       [--adam_lr ADAM_LR] [--momentum_sgd_lr MOMENTUM_SGD_LR]
#                       [--num_layer NUM_LAYER] [--mid_units MID_UNITS]
#                       [--num_filter NUM_FILTER]
#
# ハイパーパラメータ
#
# options:
#   -h, --help            show this help message and exit
#   --epoch EPOCH         epoch
#   --activation ACTIVATION
#                         ReLU or ELU
#   --optimizer OPTIMIZER
#                         Adam or MomentumSGD or rmsprop
#   --weight_decay WEIGHT_DECAY
#                         1e-10, 1e-3
#   --adam_lr ADAM_LR     1e-5, 1e-1
#   --momentum_sgd_lr MOMENTUM_SGD_LR
#                         1e-5, 1e-1
#   --num_layer NUM_LAYER
#                         3 to 7
#   --mid_units MID_UNITS
#                         100 to 500
#   --num_filter NUM_FILTER
#                         16 to 128 list

# %% [markdown]
# # Optunaによる自動パラメータ調整

# %%
run ../src/MNIST/Optuna.py
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# File ~/Parameter_tuning/src/MNIST/Optuna.py:8
#       6 import matplotlib.pyplot as plt
#       7 from torch.utils.tensorboard import SummaryWriter
# ----> 8 import optuna
#       9 optuna.logging.disable_default_handler()
#      10 from torch.utils.data import DataLoader
#
# ModuleNotFoundError: No module named 'optuna'
